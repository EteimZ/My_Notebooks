# %%
import pandas_datareader as pdr
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
path = "datasets/Stocks/"

# %% [markdown]
# Download Latest stock:

# %%
stock_data = input("Get Stock: ")
stock = pdr.get_data_yahoo(stock_data)
# Out:
# Get Stock: TSLA

# %%
stock.to_csv(path + stock_data)

# %% [markdown]
# Get list of Stocks

# %%
stocks = os.listdir('datasets/Stocks/')[:-1]

# %%
stocks
# Out:
# ['TSLA', 'ZM', 'AAPL']

# %% [markdown]
# Stock to analyze

# %%
comp_name = input("Analyze: ")
df = pd.read_csv(path + comp_name,parse_dates = True,index_col= 0)
# Out:
# Analyze: TSLA

# %%
df[['Adj Close']]
# Out:
#               Adj Close
# Date
# 2015-08-05   270.130005
# 2015-08-06   246.130005
# 2015-08-07   242.509995
# 2015-08-10   241.139999
# 2015-08-11   237.369995
# ...                 ...
# 2020-07-27  1539.599976
# 2020-07-28  1476.489990
# 2020-07-29  1499.109985
# 2020-07-30  1487.489990
# 2020-07-31  1430.760010
#
# [1257 rows x 1 columns]

# %%
df['Adj Close'].plot(figsize=(16,8),title = comp_name)
